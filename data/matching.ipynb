# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import the ratings data
ratings = pd.read_csv('raw_data/imdb_rating/imdb_rating.tsv', sep='\t', header=0)

# %%
display(ratings)
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2004
# 1        tt0000002            5.8       269
# 2        tt0000003            6.5      1904
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2685
# ...            ...            ...       ...
# 1366297  tt9916730            7.6        11
# 1366298  tt9916766            7.0        22
# 1366299  tt9916778            7.2        36
# 1366300  tt9916840            8.8         6
# 1366301  tt9916880            8.2         6
#
# [1366302 rows x 3 columns]

# %%
# Plot the distribution of ratings
plt.hist(ratings['numVotes'], bins=20)
plt.xlabel('Rating')
plt.ylabel('Number of movies')
plt.title('Distribution of ratings')

#set y axis to log scale
plt.yscale('log')
plt.show()

# %%
# Plot the distribution of ratings
plt.hist(ratings['averageRating'], bins=20)
plt.xlabel('Rating')
plt.ylabel('Number of movies')
plt.title('Distribution of ratings')

#set y axis to log scale
# plt.yscale('log')
plt.show()

# %%
# dentisy plot of ratings vs number of votes
ratings.plot.scatter(x='averageRating', y='numVotes', alpha=0.005)
plt.xlabel('Rating')
plt.ylabel('Number of votes')
plt.title('Number of votes vs rating')
plt.yscale('log')


plt.axhline(y=ratings['numVotes'].mean(), color='red') #mean
plt.axhline(y=ratings['numVotes'].median(), color='black') #median

plt.show()
